# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
df=pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df
# Out:
#          id                                          title  \
# 0   1007757                                        Swapped
# 1       278                       The Shawshank Redemption
# 2       238                                  The Godfather
# 3    687163                              Project Hail Mary
# 4       240                          The Godfather Part II
# 5       424                               Schindler's List
# 6       389                                   12 Angry Men
# 7   1330021                    Remarkably Bright Creatures
# 8       129                                  Spirited Away
# 9       155                                The Dark Knight
# 10    19404                    Dilwale Dulhania Le Jayenge
# 11      497                                 The Green Mile
# 12      122  The Lord of the Rings: The Return of the King
# 13   496243                                       Parasite
# 14  1181678                          ¿Quieres ser mi hijo?
# 15      680                                   Pulp Fiction
# 16   372058                                     Your Name.
# 17   157336                                   Interstellar
# 18      429                 The Good, the Bad and the Ugly
# 19       13                                   Forrest Gump
#
#                                              overview release_date  \
# 0   A small woodland creature and a majestic bird,...   2026-05-01
# 1   Imprisoned in the 1940s for the double murder ...   1994-09-23
# 2   Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 3   Science teacher Ryland Grace wakes up on a spa...   2026-03-15
# 4   In the continuing saga of the Corleone crime f...   1974-12-20
# 5   The true story of how businessman Oskar Schind...   1993-12-15
# 6   The defense and the prosecution have rested an...   1957-04-10
# 7   Through unlikely bonds formed during night shi...   2026-05-07
# 8   A young girl, Chihiro, becomes trapped in a st...   2001-07-20
# 9   Batman raises the stakes in his war on crime. ...   2008-07-16
# 10  Raj is a rich, carefree, happy-go-lucky second...   1995-10-20
# 11  A supernatural tale set on death row in a Sout...   1999-12-10
# 12  As armies mass for a final battle that will de...   2003-12-17
# 13  All unemployed, Ki-taek's family takes peculia...   2019-05-30
# 14  Lu, a conformist woman in her forties, learns ...   2023-09-21
# 15  A burger-loving hit man, his philosophical par...   1994-09-10
# 16  High schoolers Mitsuha and Taki are complete s...   2016-08-26
# 17  The adventures of a group of explorers who mak...   2014-11-05
# 18  While the Civil War rages on between the Union...   1966-12-23
# 19  A man with a low IQ has accomplished great thi...   1994-06-23
#
#     popularity  vote_average  vote_count
# 0     229.3482         8.974        1618
# 1      82.1095         8.722       30513
# 2      44.5504         8.687       23004
# 3     251.2943         8.666        4775
# 4      28.5329         8.572       13948
# 5      23.5327         8.569       17495
# 6      22.8868         8.562       10017
# 7      48.7964         8.563         576
# 8      34.8132         8.535       18376
# 9      38.9118         8.531       35858
# 10     17.0706         8.500        4591
# 11     29.3770         8.507       19300
# 12     44.3458         8.499       26611
# 13     34.6159         8.494       20691
# 14     12.2159         8.500         354
# 15     34.6646         8.483       30251
# 16     31.1397         8.481       12598
# 17     71.0258         8.477       39940
# 18     25.4239         8.468        9669
# 19     27.9753         8.465       29802

# %%
df=pd.DataFrame()

# %%
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df=pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df=pd.concat([df, temp_df], ignore_index=True)

# %%
df
# Out:
#            id                     title  \
# 0     1007757                   Swapped
# 1         278  The Shawshank Redemption
# 2         238             The Godfather
# 3      687163         Project Hail Mary
# 4         240     The Godfather Part II
# ...       ...                       ...
# 8555   675531              Dark Harvest
# 8556    10066              House of Wax
# 8557     2370                     Topaz
# 8558   328595                 Parallels
# 8559   209355       The French Minister
#
#                                                overview release_date  \
# 0     A small woodland creature and a majestic bird,...   2026-05-01
# 1     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 2     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 3     Science teacher Ryland Grace wakes up on a spa...   2026-03-15
# 4     In the continuing saga of the Corleone crime f...   1974-12-20
# ...                                                 ...          ...
# 8555  In a small Midwestern town, a deadly annual ri...   2023-10-11
# 8556  A group of unwitting teens are stranded near a...   2005-05-05
# 8557  Copenhagen, Denmark, 1962. When a high-ranking...   1969-12-17
# 8558  An underground MMA fighter must confront his s...   2015-03-01
# 8559  Alexandre Taillard de Vorms is a force to be r...   2013-11-06
#
#       popularity  vote_average  vote_count
# 0       229.3482         8.974        1618
# 1        82.1095         8.722       30513
# 2        44.5504         8.687       23004
# 3       251.2943         8.666        4775
# 4        28.5329         8.572       13948
# ...          ...           ...         ...
# 8555      2.2095         6.000         307
# 8556      5.4298         6.030        3348
# 8557      2.6695         6.000         417
# 8558      1.1854         6.000         390
# 8559      0.6924         6.028         302
#
# [8560 rows x 7 columns]

# %%
df.to_csv('movies.csv')
